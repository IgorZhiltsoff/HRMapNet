# %% [markdown]
# ### What am I doing?
# (should go into the report)

# %% [markdown]
# All in all, we are building a map from sensors on an autopiloted car. I'm still not sure if this is EXACTLY what this project does or if it takes a ready solution and enhances it somehow (TBH, the latter seems more likely)

# %% [markdown]
# Why are we doing that? Can't we just load a map from Google Maps? Also, if an autopiloted car is on the road, it should have *some* idea about where it is headed, so it should have *some sort of a map* already. Several reasons:
# 1. We cannot load pedestrians, obviously (although I'm not sure if pedestrian-detection comes out-of-the-box),
# 2. We cannot really rely on loading maintanance data from web mapping, or road signs, which may change without web maps being notified,
# 3. The car is probably driving by GPS which is not too precise to tell the car which lane to choose when turning on cross-roads, for example. BTW, lane detection is discussed in the MapTR article (https://arxiv.org/pdf/2208.14437), which I found to be very convincing.

# %% [markdown]
# ### Ideas

# %% [markdown]
# Can we use web maps as priors for global map?

# %% [markdown]
# Detecting dashed lane separators

# %% [markdown]
# How to penalize for extra objects?

# %% [markdown]
# How does raster take less space than vector? I guess the vector map is overblown by storing all cyclic orders of a polygon (thus, to store an $n$-gon vector map needs $2n^2$ copies of its vertices)

# %% [markdown]
# Each grey bubble needs a link
#
# Let's unwrap this model starting from DETR. At the end of the day, this net DOES segmentation to update the map.

# %% [markdown]
# Check frameworks with grep :)
#
#
# https://docs.wandb.ai/ref/python/log/ -- wandb failed

# %% [markdown]
# #### Improvements

# %% [markdown]
# Can lidars be added? -- Yes

# %% [markdown]
# Use not labels but BEV features in history map

# %% [markdown]
# Label parts of the road (highway, near school, ...; active road signs)

# %% [markdown]
# ### Plan

# %% [markdown]
# 0. Asking the supervisor if this is an OK repo, or are the Chinese fucking with me
# 1. Actually reading the code, no matter how hard it is
# 2. Debug inference and try to reverse engineering what I see

# %%
import numpy

# %%
import IPython.display
fig2 = IPython.display.Image('fig2.png')
display(fig2)
